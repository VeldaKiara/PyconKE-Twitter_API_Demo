# %%
import tweepy
from config import API_KEY, API_SECRET_KEY, ACCESS_TOKEN, ACCESS_TOKEN_SECRET,BEARER_TOKEN
import pandas as pd

# %%
# Setup access to API
def connect_to_twitter_OAuth():
    auth = tweepy.OAuthHandler(API_KEY, API_SECRET_KEY)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

    api = tweepy.API(auth)
    return api

# %%
# Create API object
api = connect_to_twitter_OAuth()

# tweets from Elon Musk, random tweets
python_tweets = api.user_timeline(screen_name ='pythonairobi')
for tweet in elon_tweets:
    print(tweet.text)
# Out:
# RT @arlemi: Very much looking forward to be in Nairobi next week for #PyConKE!
#
# I'll talk about the benefits of an API-first approach and…
# Ticketing Updates:
#
# ✅ Ticket Sales for PyCON KE will increase to KES 2,000 on Friday 29th April
#
# ✅ Ticket Sales Clo… https://t.co/EqMWuxWnCi
# RT @NancieMumbo: @Kasungwa_ go girl 👏👏👏👏
# RT @NdemoKelvin: @getpostman will be in the house for Pycon KE 2022, get your tickets at https://t.co/vf8sYUcjHz today to attend the bigges…
# You should definitely not miss this one🥳🥳, we will be hosting @arlemi , a Senior Developer Advocate🥑@getpostman  to… https://t.co/hl3pIvsMUb
# RT @Kasungwa_: Your Girl is a speaker ☺
# Looking forward to meeting you all @jemiahsius @RabbiGreenberg 😌 https://t.co/RIEGTlwtRt
# Next, @NdemoKelvin , Software Engineer @TwigaFoods  will be taking us through Building APIs with Django Rest Framew… https://t.co/lXe72I5tOj
# We are also excited to be hosting the amazing @jemiahsius, Director of Developer Relations @newrelic, Jemiah will b… https://t.co/vHUMJn4TMC
# Network science sounds like something interesting, right? well, @Mridul_Seth, an Open Source Software Engineer will… https://t.co/Yfz350EAxm
# Next in line is Thuo Ng'ang'a, an SRE Engineer @TwigaFoods , Thuo will be taking us through Containers and Environm… https://t.co/gbHDFC0T8J
# More icing on the Cake🤭, we will also be hosting Rose Delilah Gesicho, a technical Mentor @moringaschool and Commun… https://t.co/JOxRYMpwLw
# Samuel Olembo, a Software Engineer @TwigaFoods will be talking how Python is used to build Twiga Foods infrastructu… https://t.co/friJ18S3mp
# @cyrilmichino is next in line to take us through Big Data Engineering with Python and Apache Spark, he is the found… https://t.co/4nSVA5a16E
# Come learn GraphQL APIs with Django by Grace Zawadi(@zawadi_g_), a technical mentor @SkaeHub
#
# Get your ticket -&gt;… https://t.co/6cro9H7RQA
# Next in line, we have @iamukasa , Co Founder at Sophie Bot, Irving will be talking about Deploying your AI model th… https://t.co/eP2iZl847p
# Our next speaker is @GrishonNganga, who will be talking about Intro to Web3 Development with Python
#
# @b1ackd0t https://t.co/7R0zqBsS9b
# Our next speaker is in line is Hellen Mati, a data scientist who will be talking about Leveraging Python to Future… https://t.co/3RrOb9xd3n
# Just a few announcements:
# - We hope everyone has received their ticket. If you haven't please check your spam.
# - We… https://t.co/Phyz8pnhuc
# Next in our lineup is  @William__Otieno, William will be taking us through Multi-tenant architecture in Django. Wil… https://t.co/5hM7dqNp0R

# %%
# fuction to extract data from tweet object
def extract_tweet_attributes(tweet_object):
    # create empty list
    tweet_list =[]
    # loop through tweet objects
    for tweet in tweet_object:
        tweet_id = tweet.id # unique integer identifier for tweet
        text = tweet.text # utf-8 text of tweet
        favorite_count = tweet.favorite_count
        retweet_count = tweet.retweet_count
        created_at = tweet.created_at # utc time tweet created
        source = tweet.source # utility used to post tweet
        reply_to_status = tweet.in_reply_to_status_id # if reply int of orginal tweet id
        reply_to_user = tweet.in_reply_to_screen_name # if reply original tweetes screenname
        retweets = tweet.retweet_count # number of times this tweet retweeted
        favorites = tweet.favorite_count # number of time this tweet liked
        # append attributes to list
        tweet_list.append({'tweet_id':tweet_id, 
                          'text':text, 
                          'favorite_count':favorite_count,
                          'retweet_count':retweet_count,
                          'created_at':created_at, 
                          'source':source, 
                          'reply_to_status':reply_to_status, 
                          'reply_to_user':reply_to_user,
                          'retweets':retweets,
                          'favorites':favorites})
    # create dataframe   
    df = pd.DataFrame(tweet_list, columns=['tweet_id',
                                           'text',
                                           'favorite_count',
                                           'retweet_count',
                                           'created_at',
                                           'source',
                                           'reply_to_status',
                                           'reply_to_user',
                                           'retweets',
                                           'favorites'])
    return df

# %%
extract_tweet_attributes(python_tweets)
''' if you want to save the data to a csv file
df.to_csv('file1.csv')
'''
# Out:
#                tweet_id                                               text  \
# 0   1519283815696539649  RT @arlemi: Very much looking forward to be in...
# 1   1519274909377175552  Ticketing Updates:\n\n✅ Ticket Sales for PyCON...
# 2   1519264291244945408           RT @NancieMumbo: @Kasungwa_ go girl 👏👏👏👏
# 3   1519263564879605762  RT @NdemoKelvin: @getpostman will be in the ho...
# 4   1519260840263917570  You should definitely not miss this one🥳🥳, we ...
# 5   1519202544047771648            RT @Kasungwa_: Your Girl is a speaker ☺
# 6   1518942982392758277  Looking forward to meeting you all @jemiahsius...
# 7   1518942663290019843  Next, @NdemoKelvin , Software Engineer @TwigaF...
# 8   1518941536251174916  We are also excited to be hosting the amazing ...
# 9   1518940155469615104  Network science sounds like something interest...
# 10  1518939082285621251  Next in line is Thuo Ng'ang'a, an SRE Engineer...
# 11  1518938074830581762  More icing on the Cake🤭, we will also be hosti...
# 12  1518935631103250439  Samuel Olembo, a Software Engineer @TwigaFoods...
# 13  1518934598083919874  @cyrilmichino is next in line to take us throu...
# 14  1518933781021077504  Come learn GraphQL APIs with Django by Grace Z...
# 15  1518932861042180099  Next in line, we have @iamukasa , Co Founder a...
# 16  1518932279304896513  Our next speaker is @GrishonNganga, who will b...
# 17  1518931826630397952  Our next speaker is in line is Hellen Mati, a ...
# 18  1518839005462339584  Just a few announcements:\n- We hope everyone ...
# 19  1517884751184605185  Next in our lineup is  @William__Otieno, Willi...
#
#     favorite_count  retweet_count                created_at  \
# 0                0              8 2022-04-27 11:54:23+00:00
# 1                1              0 2022-04-27 11:18:59+00:00
# 2                0              2 2022-04-27 10:36:48+00:00
# 3                0              4 2022-04-27 10:33:55+00:00
# 4               17              8 2022-04-27 10:23:05+00:00
# 5                0             79 2022-04-27 06:31:26+00:00
# 6                7              3 2022-04-26 13:20:02+00:00
# 7               35             13 2022-04-26 13:18:46+00:00
# 8               20              7 2022-04-26 13:14:17+00:00
# 9               11              6 2022-04-26 13:08:48+00:00
# 10              41             15 2022-04-26 13:04:32+00:00
# 11              20              9 2022-04-26 13:00:32+00:00
# 12              38             15 2022-04-26 12:50:49+00:00
# 13              14              9 2022-04-26 12:46:43+00:00
# 14              22             16 2022-04-26 12:43:28+00:00
# 15              10              6 2022-04-26 12:39:49+00:00
# 16               8              3 2022-04-26 12:37:30+00:00
# 17              88             38 2022-04-26 12:35:42+00:00
# 18              34             12 2022-04-26 06:26:52+00:00
# 19              62             14 2022-04-23 15:15:00+00:00
#
#                 source reply_to_status reply_to_user  retweets  favorites
# 0   Twitter for iPhone            None          None         8          0
# 1      Twitter Web App            None          None         0          1
# 2      Twitter Web App            None          None         2          0
# 3   Twitter for iPhone            None          None         4          0
# 4      Twitter Web App            None          None         8         17
# 5   Twitter for iPhone            None          None        79          0
# 6      Twitter Web App            None          None         3          7
# 7      Twitter Web App            None          None        13         35
# 8      Twitter Web App            None          None         7         20
# 9      Twitter Web App            None          None         6         11
# 10     Twitter Web App            None          None        15         41
# 11     Twitter Web App            None          None         9         20
# 12     Twitter Web App            None          None        15         38
# 13     Twitter Web App            None  cyrilmichino         9         14
# 14     Twitter Web App            None          None        16         22
# 15     Twitter Web App            None          None         6         10
# 16     Twitter Web App            None          None         3          8
# 17     Twitter Web App            None          None        38         88
# 18     Twitter Web App            None          None        12         34
# 19     Twitter Web App            None          None        14         62
